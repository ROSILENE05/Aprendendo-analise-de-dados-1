# %% [markdown]
# ## Meu primeiro Portfólio em Python

# %% [markdown]
# ## empresas de telecomunicações no Brasil

# %%
import pandas as pd

# %%
df = pd.read_csv('AcessosTVAssinaturaTotal.csv')
df.head()
# Out:
#    Ano;Mês;Acessos
# 0  2020;8;15129433
# 1  2020;7;15060698
# 2  2020;6;15078395
# 3  2020;5;15145723
# 4  2020;4;15221399

# %%
df.count
# Out:
# <bound method DataFrame.count of      Ano;Mês;Acessos
# 0    2020;8;15129433
# 1    2020;7;15060698
# 2    2020;6;15078395
# 3    2020;5;15145723
# 4    2020;4;15221399
# ..               ...
# 99   2012;5;14295810
# 100  2012;4;13959439
# 101  2012;3;13675633
# 102  2012;2;13319510
# 103  2012;1;13054002
#
# [104 rows x 1 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Ano;Mês;Acessos
# 0    2020;8;15129433
# 1    2020;7;15060698
# 2    2020;6;15078395
# 3    2020;5;15145723
# 4    2020;4;15221399
# ..               ...
# 99   2012;5;14295810
# 100  2012;4;13959439
# 101  2012;3;13675633
# 102  2012;2;13319510
# 103  2012;1;13054002
#
# [104 rows x 1 columns]>

# %%
df.dtypes
# Out:
# Ano;Mês;Acessos    object
# dtype: object

# %%
# %matplotlib inline

# %%
df.columns = ['acessos']

# %%
df['acessos'].value_counts().plot.barh(title = 'acessos das empresas')

# %%
L = ['1','2','3','4']print("".join(L))
# Out:
#   File "<ipython-input-9-0b2a435ff7ad>", line 1
#     L = ['1','2','3','4']print("".join(L))
#                          ^
# SyntaxError: invalid syntax

# %%
a = (1,2,3,"hello world")

# %%
b = {'a':[1,2,3],'b':(1,2,3),'c':'hello world'}

# %%
c = [1,[1,2],{'hello':'world'},{1,2}]

# %%
print (type("x"))

# %%
any_number = 10

# %%
try: any_number = float(any_number/0)
    except zero divisor error:
# Out:
#   File "<ipython-input-15-0310e3153caa>", line 2
#     except zero divisor error:
#     ^
# IndentationError: unexpected indent

# %%
print('why are you doing that?' = str(any_number), end = '==')
# Out:
#   File "<ipython-input-13-2cbdd88e8058>", line 1
#     print('why are you doing that?' = str(any_number), end = '==')
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
